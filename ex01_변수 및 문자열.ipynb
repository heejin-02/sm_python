# %% [markdown]
# #### 변수와 문자열을 배워보자

# %%
#print : 출력해주는 내장함수

print('안녕')
# Out:
# 안녕

# %% [markdown]
# ![image.png](attachment:426c48fe-065d-47dc-9854-d1919a90cbd4.png)

# %% [markdown]
# ![image.png](attachment:fe4dfa78-722b-4271-95ed-d61e67b21211.png)

# %%
# 간단한 변수 선언
num = 3

# %%
#print(num) 3 print함수를 이용하여 num을 출력
num #num 3 변수 호출
# Out:
# 3

# %%
#type : 변수의 타입
type(num)
# Out:
# int

# %%
float(num)
# Out:
# 3.0

# %%
print(num)
type(num)

# float() : 실수형으로 변환한 값을 반환
# 변수 자체의 값에는 영향이 없다.
# Out:
# 3
# int

# %%
num = float(num)
type(num)
# Out:
# float

# %%
num = 3.0
type(num)
# Out:
# float

# %% [markdown]
# ### 변수명 규칙
# - 영문자, 숫자, 언더바 사용 가능
# - 숫자 시작 불가능
# - 키워드 사용 불가능(if, and, True 등등)

# %% [markdown]
# ### 권장사항
# - 변수명의 첫글자는 항상 소문자
# - 두가지의 문자를 섞을 경우 두 단어를 구분
#   - number_list
#   - NumberList
#   - numberList

# %%
a = 10
b = 15
c = '멋쟁이'

print(a)
print(b)
print(c)
# Out:
# 10
# 15
# 멋쟁이

# %%
# 파이썬 변수 선언 특징
d, e = 20, 30
e
# Out:
# 30

# %%
str1 = str2 = '파이썬 수업 듣는중'

# %%
# print 내부 , 로 구분 가능
print(c, str2)
# Out:
# 멋쟁이 파이썬 수업 듣는중

# %%
print(c+str2)
# Out:
# 멋쟁이파이썬 수업 듣는중

# %%
# 키워드(예약어) 사용 불가능
if = 30
if
# Out:
#   Cell In[39], line 2
#     if = 30
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# print = 4
# 내장함수명을 사용하게 되면, 내장함수의 기능을 잃는다

# %% [markdown]
# ![image.png](attachment:0f7aa88e-e57b-4c99-af31-10b0adbd405d.png)

# %%
x = 100
y = 200
sum = x+y #sum 내장함수 기능을 바꿔버렸다..
print(sum)
# Out:
# 300

# %% [markdown]
# ### 이스케이프 코드

# %% [markdown]
# ![image.png](attachment:de4bd7d4-09c9-4008-9f05-a3484f550e2c.png)

# %%
# she's gone

#str3 = 'she\'s gone'
str = "she's gone"
print(str3)
# Out:
# she's gone

# %%
str4 = '''이렇게
여러줄을
입력 가능하다'''

print(str4)
# Out:
# 이렇게
# 여러줄을
# 입력 가능하다

# %%
str4
# Out:
# '이렇게\n여러줄을\n입력 가능하다'

# %%
print(a)
'''
문자열 부분은 실행되지 않는다.
파이썬에서는 주석처럼 사용
'''
print(b)
# Out:
# 10
# 15

# %% [markdown]
# ![image.png](attachment:4eeabfe4-9ca0-4df7-b9b9-43393a4f57dc.png)

# %%
day = "2020년 3월 3일의 날씨는 맑음입니다."

# %%
print("날짜 :", day[:11])
print("날씨 :", day[-6:-4])
# Out:
# 날짜 : 2020년 3월 3일
# 날씨 : 맑음

# %% [markdown]
# ### 문자열 포매팅
# - 문자열 안의 특정한 값을 바꿔야하는 경우

# %%
s1 = '오늘은 3월 25일 입니다.'
s1 = '오늘은 3월 26일 입니다.'
print(s1)
# Out:
# 오늘은 3월 26일 입니다.

# %%
# % 기호를 사용하는 방법
day = 22
# 정수형 변수를 넣을 자리에 %d, 마지막에 들어갈 %들어갈 변수명
s1 = '오늘은 3월 %d일 입니다.'%day

# %d : 정수형
# %f : 실수형
# %s : 문자형

print(s1)
# Out:
# 오늘은 3월 22일 입니다.

# %%
day += 1
# day = day + 1
print('오늘은 3월 %d일 입니다.'%day)
# Out:
# 오늘은 3월 31일 입니다.

# %%
# format 함수를 사용한 포매팅
month = 3
day = '이십오'

# .format(첫번째 변수, 두번째 변수,...)
# 자료형이 달라져도 상관없다
s = '오늘은 {}월 {}일 입니다.'.format(month,day)

print(s)
# Out:
# 오늘은 3월 이십오일 입니다.

# %%
# f문자열을 사용한 포매팅
# 현재 가장 많이 쓰이는 방법. python3 부터 제공하는 기능

month = 4
day = 5

s = f'오늘은 {month}월 {day}일 입니다.'
print(s)
# Out:
# 오늘은 4월 5일 입니다.

# %% [markdown]
# # 3/26 수업

# %% [markdown]
# ![image.png](attachment:d50cf024-8eea-4682-8fba-47a40baad1cf.png)

# %%
x = 100
y = 200
sum2 = x+y
print(f'{x}와 {y}의 합은 {sum2}입니다.')
# Out:
# 100와 200의 합은 300입니다.

# %%
# 사용자로부터 값을 입력받아서 변수에 저장 : input

name = input('이름을 입력하세요 : ')
print(name)
# Out:
# 이름을 입력하세요 :  ㅎㅈ
# ㅎㅈ

# %% [markdown]
# ### 실습. 팀장의 이름을 입력받아, 팀장의 성과 이름을 출력해보자
# - 입력된 값이 저장된 name에서 인덱싱과 슬라이싱
# - 문자열 포매팅

# %%
name = input('팀장 이름 입력 : ')
last_name = name[0]
first_name = name[1:]
print(f'팀장의 이름은 {first_name}이고, 성은 {last_name} 입니다.')
# Out:
# 팀장 이름 입력 :  오희진
# 팀장의 이름은 희진이고, 성은 오 입니다.
